# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import os

# --- Configuration ---
IMAGE_SIZE = (160, 160)
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000
AUTOTUNE = tf.data.AUTOTUNE
EPOCHS_FINE_TUNE = 40
BASE_MODEL_TRAINABLE_LAYERS = 70
MODEL_SAVE_PATH = './stanford_dogs_model'
PLOTS_SAVE_DIR = './training_plots_MobileNetV3'
DROPOUT_RATE = 0.3

os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
os.makedirs(PLOTS_SAVE_DIR, exist_ok=True)

# --- 1. Load and Prepare Data ---
print("Loading Stanford Dogs dataset...")
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
    as_supervised=True,
)

num_classes = ds_info.features['label'].num_classes
print(f"Number of classes: {num_classes}")

# --- Preprocessing and Enhanced Augmentation ---
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(factor=0.1),
    tf.keras.layers.RandomZoom(height_factor=0.2, width_factor=0.2),
])

def resize_image(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    return image, label

def apply_augmentation(image, label):
    image = data_augmentation(image, training=True)
    image = tf.image.random_brightness(image, max_delta=50)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
    image = tf.image.random_saturation(image, lower=0.7, upper=1.3)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.clip_by_value(image, 0.0, 255.0)
    return image, label

def mobilenet_preprocess(image, label):
    image = tf.keras.applications.mobilenet_v3.preprocess_input(image)
    return image, label

# Build the data pipeline
ds_train = ds_train.map(resize_image, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.map(apply_augmentation, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.map(mobilenet_preprocess, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

ds_test = ds_test.map(resize_image, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.map(mobilenet_preprocess, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.batch(BATCH_SIZE).prefetch(AUTOTUNE)

print("Dataset preprocessing complete with fixed TF-native augmentation.")

# --- 2. Choose and Build the Model ---
print("Building the model using MobileNetV3 with Dropout...")

base_model = tf.keras.applications.MobileNetV3Small(
    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
dropout_layer = tf.keras.layers.Dropout(DROPOUT_RATE)
prediction_layer = tf.keras.layers.Dense(num_classes, activation='softmax')

model = tf.keras.Sequential([
    base_model,
    global_average_layer,
    dropout_layer,
    prediction_layer
])

# --- 3. Set up the Training Process ---
print("Compiling the model for initial training...")
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()

# Initial training
print("Starting initial training (training only the top layers)...")
initial_epochs = 10
history = model.fit(ds_train,
                    epochs=initial_epochs,
                    validation_data=ds_test)

print("Initial training complete.")

# --- Fine-tuning ---
print("Starting fine-tuning (unfreezing and training some base model layers)...")
base_model.trainable = True
for layer in base_model.layers[:-BASE_MODEL_TRAINABLE_LAYERS]:
    layer.trainable = False

fine_tune_learning_rate = base_learning_rate / 10
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_learning_rate),
              metrics=['accuracy'])

model.summary()

fine_tune_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=15, monitor='val_loss', restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(MODEL_SAVE_PATH, 'MobileNetV3_best_model.keras'),
                                       monitor='val_accuracy', save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_lr=fine_tune_learning_rate * 0.01)
]

# Continue training
print("Fine-tuning complete.")

history_fine_tune = model.fit(ds_train,
                              epochs=initial_epochs + EPOCHS_FINE_TUNE,
                              initial_epoch=initial_epochs,
                              validation_data=ds_test,
                              callbacks=fine_tune_callbacks)

# --- Save the Model ---
print(f"Saving the final trained model state to {os.path.join(MODEL_SAVE_PATH, 'MobileNetV3_final_model.keras')}...")
model.save(os.path.join(MODEL_SAVE_PATH, 'MobileNetV3_final_model.keras'))
print("Final model state saved.")
print(f"Best model saved during training can be found at {os.path.join(MODEL_SAVE_PATH, 'MobileNetV3_best_model.keras')}")

# --- Visualize Training ---
acc = history.history['accuracy'] + history_fine_tune.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine_tune.history['val_accuracy']
loss = history.history['loss'] + history_fine_tune.history['loss']
val_loss = history.history['val_loss'] + history_fine_tune.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning', linestyle='--')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning', linestyle='--')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# 2025-05-06 16:36:52.399368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746529612.415328   17174 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746529612.420202   17174 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746529612.432528   17174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746529612.432544   17174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746529612.432546   17174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746529612.432548   17174 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-06 16:36:52.436476: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading Stanford Dogs dataset...
# I0000 00:00:1746529615.282479   17174 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3131 MB memory:  -> device: 0, name: Quadro P1000, pci bus id: 0000:01:00.0, compute capability: 6.1
# Number of classes: 120
# Dataset preprocessing complete with fixed TF-native augmentation.
# Building the model using MobileNetV3 with Dropout...
# /home/igris/py/lib/python3.12/site-packages/keras/src/applications/mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Compiling the model for initial training...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobileNetV3Small (Functional)   │ (None, 5, 5, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 576)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │        69,240 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,008,360 (3.85 MB)
#  Trainable params: 69,240 (270.47 KB)
#  Non-trainable params: 939,120 (3.58 MB)
# Starting initial training (training only the top layers)...
# Epoch 1/10
# 2025-05-06 16:37:02.382495: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746529623.515535   17251 service.cc:152] XLA service 0x7a428c0b4a20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746529623.515578   17251 service.cc:160]   StreamExecutor device (0): Quadro P1000, Compute Capability 6.1
# 2025-05-06 16:37:03.627409: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746529624.391595   17251 cuda_dnn.cc:529] Loaded cuDNN version 90501
#   3/375 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.0260 - loss: 6.0616
# I0000 00:00:1746529632.133085   17251 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 86ms/step - accuracy: 0.0111 - loss: 5.3709 - val_accuracy: 0.0382 - val_loss: 4.5023
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.0334 - loss: 4.7231 - val_accuracy: 0.1069 - val_loss: 3.9717
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - accuracy: 0.0723 - loss: 4.3049 - val_accuracy: 0.1833 - val_loss: 3.5734
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - accuracy: 0.1022 - loss: 4.0168 - val_accuracy: 0.2472 - val_loss: 3.2668
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.1405 - loss: 3.7548 - val_accuracy: 0.2963 - val_loss: 3.0291
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - accuracy: 0.1741 - loss: 3.5609 - val_accuracy: 0.3348 - val_loss: 2.8376
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.3471 - loss: 2.4395 - val_accuracy: 0.4688 - val_loss: 1.9650 - learning_rate: 1.0000e-05
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 37s 96ms/step - accuracy: 0.3526 - loss: 2.4368 - val_accuracy: 0.4709 - val_loss: 1.9548 - learning_rate: 1.0000e-05
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.3651 - loss: 2.3796 - val_accuracy: 0.4728 - val_loss: 1.9447 - learning_rate: 1.0000e-05
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.3628 - loss: 2.4174 - val_accuracy: 0.4749 - val_loss: 1.9310 - learning_rate: 1.0000e-05
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 33s 84ms/step - accuracy: 0.3653 - loss: 2.3908 - val_accuracy: 0.4794 - val_loss: 1.9203 - learning_rate: 1.0000e-05
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 33s 84ms/step - accuracy: 0.3642 - loss: 2.3959 - val_accuracy: 0.4791 - val_loss: 1.9127 - learning_rate: 1.0000e-05
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.3733 - loss: 2.3645 - val_accuracy: 0.4812 - val_loss: 1.9044 - learning_rate: 1.0000e-05
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.3751 - loss: 2.3371 - val_accuracy: 0.4829 - val_loss: 1.8955 - learning_rate: 1.0000e-05
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.3825 - loss: 2.3042 - val_accuracy: 0.4852 - val_loss: 1.8866 - learning_rate: 1.0000e-05
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 94ms/step - accuracy: 0.3750 - loss: 2.2998 - val_accuracy: 0.4867 - val_loss: 1.8779 - learning_rate: 1.0000e-05
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 35s 91ms/step - accuracy: 0.3856 - loss: 2.2867 - val_accuracy: 0.4860 - val_loss: 1.8749 - learning_rate: 1.0000e-05
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 33s 86ms/step - accuracy: 0.3808 - loss: 2.2972 - val_accuracy: 0.4876 - val_loss: 1.8687 - learning_rate: 1.0000e-05
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 34s 88ms/step - accuracy: 0.3862 - loss: 2.2608 - val_accuracy: 0.4910 - val_loss: 1.8606 - learning_rate: 1.0000e-05
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 35s 91ms/step - accuracy: 0.3983 - loss: 2.2568 - val_accuracy: 0.4909 - val_loss: 1.8527 - learning_rate: 1.0000e-05
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.3984 - loss: 2.2188 - val_accuracy: 0.4929 - val_loss: 1.8418 - learning_rate: 1.0000e-05
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.3971 - loss: 2.2230 - val_accuracy: 0.4939 - val_loss: 1.8356 - learning_rate: 1.0000e-05
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.4078 - loss: 2.2003 - val_accuracy: 0.4967 - val_loss: 1.8348 - learning_rate: 1.0000e-05
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.3949 - loss: 2.2029 - val_accuracy: 0.4987 - val_loss: 1.8232 - learning_rate: 1.0000e-05
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.4112 - loss: 2.1903 - val_accuracy: 0.5000 - val_loss: 1.8175 - learning_rate: 1.0000e-05
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 35s 91ms/step - accuracy: 0.4111 - loss: 2.1747 - val_accuracy: 0.5000 - val_loss: 1.8187 - learning_rate: 1.0000e-05
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.4204 - loss: 2.1565 - val_accuracy: 0.5001 - val_loss: 1.8153 - learning_rate: 1.0000e-05
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.4176 - loss: 2.1704 - val_accuracy: 0.5007 - val_loss: 1.8075 - learning_rate: 1.0000e-05
# Saving the final trained model state to ./stanford_dogs_model/MobileNetV3_final_model.keras...
# Final model state saved.
# Best model saved during training can be found at ./stanford_dogs_model/MobileNetV3_best_model.keras
# Text(0, 0.5, 'Loss')

# %%
import tensorflow as tf
import gc
del model
gc.collect()
tf.keras.backend.clear_session()

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

model = tf.keras.models.load_model('./stanford_dogs_model/MobileNetV3_final_model.keras')

(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs', 
    split=['train', 'test'],
    with_info=True,
    as_supervised=True
)

ds_all = ds_train.concatenate(ds_test)

IMG_SIZE = model.input_shape[1:3]

def preprocess(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.keras.applications.mobilenet_v3.preprocess_input(image)
    return image, label

autotune = tf.data.AUTOTUNE
batch_size = 32

ds_all = ds_all.map(preprocess, num_parallel_calls=autotune)
ds_all = ds_all.batch(batch_size).prefetch(autotune)

pred_probs = model.predict(ds_all, verbose=1)
pred_labels = np.argmax(pred_probs, axis=1)

true_labels = np.concatenate([y.numpy() for _, y in ds_all], axis=0)

class_names = ds_info.features['label'].names

print(classification_report(true_labels, pred_labels, target_names=class_names))

cm = confusion_matrix(true_labels, pred_labels)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Out:
# 644/644 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step
#                                           precision    recall  f1-score   support
#
#                      n02085620-chihuahua       0.41      0.29      0.34       152
#               n02085782-japanese_spaniel       0.67      0.76      0.71       185
#                    n02085936-maltese_dog       0.66      0.60      0.63       252
#                       n02086079-pekinese       0.49      0.53      0.51       149
#                       n02086240-shih-tzu       0.48      0.31      0.38       214
#               n02086646-blenheim_spaniel       0.67      0.67      0.67       188
#                       n02086910-papillon       0.83      0.60      0.70       196
#                    n02087046-toy_terrier       0.68      0.47      0.55       172
#            n02087394-rhodesian_ridgeback       0.32      0.37      0.34       172
#                   n02088094-afghan_hound       0.55      0.69      0.62       239
#                         n02088238-basset       0.44      0.49      0.47       175
#                         n02088364-beagle       0.48      0.51      0.50       195
#                     n02088466-bloodhound       0.54      0.50      0.52       187
#                       n02088632-bluetick       0.65      0.62      0.64       171
#        n02089078-black-and-tan_coonhound       0.57      0.65      0.61       159
#                   n02089867-walker_hound       0.46      0.45      0.45       153
#               n02089973-english_foxhound       0.52      0.44      0.48       157
#                        n02090379-redbone       0.34      0.53      0.41       148
#                         n02090622-borzoi       0.56      0.42      0.48       151
#                n02090721-irish_wolfhound       0.36      0.22      0.28       218
#              n02091032-italian_greyhound       0.33      0.52      0.40       182
#                        n02091134-whippet       0.38      0.33      0.35       187
#                   n02091244-ibizan_hound       0.54      0.52      0.53       188
#             n02091467-norwegian_elkhound       0.70      0.69      0.70       196
#                     n02091635-otterhound       0.75      0.54      0.63       151
#                         n02091831-saluki       0.51      0.31      0.39       200
#             n02092002-scottish_deerhound       0.58      0.71      0.64       232
#                     n02092339-weimaraner       0.52      0.71      0.60       160
#      n02093256-staffordshire_bullterrier       0.47      0.43      0.45       155
# n02093428-american_staffordshire_terrier       0.43      0.32      0.36       164
#             n02093647-bedlington_terrier       0.61      0.81      0.69       182
#                 n02093754-border_terrier       0.48      0.76      0.59       172
#             n02093859-kerry_blue_terrier       0.66      0.69      0.67       179
#                  n02093991-irish_terrier       0.48      0.55      0.51       169
#                n02094114-norfolk_terrier       0.49      0.44      0.46       172
#                n02094258-norwich_terrier       0.48      0.39      0.43       185
#              n02094433-yorkshire_terrier       0.54      0.43      0.48       164
#        n02095314-wire-haired_fox_terrier       0.81      0.61      0.70       157
#               n02095570-lakeland_terrier       0.63      0.17      0.27       197
#               n02095889-sealyham_terrier       0.71      0.79      0.75       202
#                       n02096051-airedale       0.68      0.49      0.57       202
#                          n02096177-cairn       0.48      0.43      0.46       197
#             n02096294-australian_terrier       0.57      0.66      0.61       196
#                     n02109961-eskimo_dog       0.31      0.35      0.33       150
#                       n02110063-malamute       0.49      0.48      0.49       178
#                 n02110185-siberian_husky       0.38      0.14      0.20       192
#                  n02110627-affenpinscher       0.49      0.78      0.60       150
#                        n02110806-basenji       0.49      0.43      0.46       209
#                            n02110958-pug       0.50      0.62      0.56       200
#                       n02111129-leonberg       0.84      0.69      0.75       210
#                   n02111277-newfoundland       0.51      0.48      0.49       195
#                 n02111500-great_pyrenees       0.44      0.46      0.45       213
#                        n02111889-samoyed       0.66      0.72      0.69       218
#                     n02112018-pomeranian       0.67      0.72      0.69       219
#                           n02112137-chow       0.76      0.69      0.72       196
#                       n02112350-keeshond       0.72      0.90      0.80       158
#              n02112706-brabancon_griffon       0.75      0.75      0.75       153
#                       n02113023-pembroke       0.58      0.57      0.57       181
#                       n02113186-cardigan       0.49      0.35      0.41       155
#                     n02113624-toy_poodle       0.48      0.39      0.43       151
#               n02113712-miniature_poodle       0.42      0.13      0.20       155
#                n02113799-standard_poodle       0.48      0.21      0.30       159
#               n02113978-mexican_hairless       0.51      0.86      0.64       155
#                          n02115641-dingo       0.42      0.67      0.51       156
#                          n02115913-dhole       0.78      0.78      0.78       150
#            n02116738-african_hunting_dog       0.82      0.92      0.87       169
#
#                                 accuracy                           0.55     20580
#                                macro avg       0.55      0.55      0.54     20580
#                             weighted avg       0.55      0.55      0.54     20580
# 2025-05-06 17:06:40.189577: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import tensorflow as tf
import gc
del model
gc.collect()
tf.keras.backend.clear_session()

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

model = tf.keras.models.load_model('./stanford_dogs_model/MobileNetV3_best_model.keras')

(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs', 
    split=['train', 'test'],
    with_info=True,
    as_supervised=True
)

ds_all = ds_train.concatenate(ds_test)

IMG_SIZE = model.input_shape[1:3]

def preprocess(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.keras.applications.mobilenet_v3.preprocess_input(image)
    return image, label

autotune = tf.data.AUTOTUNE
batch_size = 32

ds_all = ds_all.map(preprocess, num_parallel_calls=autotune)
ds_all = ds_all.batch(batch_size).prefetch(autotune)

pred_probs = model.predict(ds_all, verbose=1)
pred_labels = np.argmax(pred_probs, axis=1)

true_labels = np.concatenate([y.numpy() for _, y in ds_all], axis=0)

class_names = ds_info.features['label'].names

print(classification_report(true_labels, pred_labels, target_names=class_names))

cm = confusion_matrix(true_labels, pred_labels)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Out:
# 644/644 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step
#                                           precision    recall  f1-score   support
#
#                      n02085620-chihuahua       0.41      0.29      0.34       152
#               n02085782-japanese_spaniel       0.67      0.76      0.71       185
#                    n02085936-maltese_dog       0.66      0.60      0.63       252
#                       n02086079-pekinese       0.49      0.53      0.51       149
#                       n02086240-shih-tzu       0.48      0.31      0.38       214
#               n02086646-blenheim_spaniel       0.67      0.67      0.67       188
#                       n02086910-papillon       0.83      0.60      0.70       196
#                    n02087046-toy_terrier       0.68      0.47      0.55       172
#            n02087394-rhodesian_ridgeback       0.32      0.37      0.34       172
#                   n02088094-afghan_hound       0.55      0.69      0.62       239
#                         n02088238-basset       0.44      0.49      0.47       175
#                         n02088364-beagle       0.48      0.51      0.50       195
