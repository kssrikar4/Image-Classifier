# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import os

IMAGE_SIZE = (160, 160)
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000
AUTOTUNE = tf.data.AUTOTUNE
EPOCHS_FINE_TUNE = 40
BASE_MODEL_TRAINABLE_LAYERS = 70
MODEL_SAVE_PATH = './stanford_dogs_model'
PLOTS_SAVE_DIR = './training_plots_EfficientNetB1'
DROPOUT_RATE = 0.3

os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
os.makedirs(PLOTS_SAVE_DIR, exist_ok=True)

print("Loading Stanford Dogs dataset...")
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
    as_supervised=True,
)

num_classes = ds_info.features['label'].num_classes
print(f"Number of classes: {num_classes}")

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(factor=0.1),
    tf.keras.layers.RandomZoom(height_factor=0.2, width_factor=0.2),
])

def resize_image(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    return image, label

def apply_augmentation(image, label):
    image = data_augmentation(image, training=True)
    image = tf.image.random_brightness(image, max_delta=50)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
    image = tf.image.random_saturation(image, lower=0.7, upper=1.3)
    image = tf.image.random_hue(image, max_delta=0.1)
    image = tf.clip_by_value(image, 0.0, 255.0)
    return image, label

def efficientnet_preprocess(image, label):
    image = tf.keras.applications.efficientnet.preprocess_input(image)
    return image, label

ds_train = ds_train.map(resize_image, num_parallel_calls=AUTOTUNE)
nds_train = ds_train.map(apply_augmentation, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.map(efficientnet_preprocess, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE).prefetch(AUTOTUNE)

ds_test = ds_test.map(resize_image, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.map(efficientnet_preprocess, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.batch(BATCH_SIZE).prefetch(AUTOTUNE)

print("Dataset preprocessing complete with fixed TF-native augmentation.")

print("Building the model using EfficientNetB1 with Dropout...")

base_model = tf.keras.applications.EfficientNetB1(
    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
dropout_layer = tf.keras.layers.Dropout(DROPOUT_RATE)
prediction_layer = tf.keras.layers.Dense(num_classes, activation='softmax')

model = tf.keras.Sequential([
    base_model,
    global_average_layer,
    dropout_layer,
    prediction_layer
])

print("Compiling the model for initial training...")
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()

print("Starting initial training (training only the top layers)...")
initial_epochs = 10
history = model.fit(ds_train,
                    epochs=initial_epochs,
                    validation_data=ds_test)

print("Initial training complete.")

print("Starting fine-tuning (unfreezing and training some base model layers)...")

base_model.trainable = True
for layer in base_model.layers[:-BASE_MODEL_TRAINABLE_LAYERS]:
    layer.trainable = False

fine_tune_learning_rate = base_learning_rate / 10
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_learning_rate),
              metrics=['accuracy'])

model.summary()

fine_tune_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=15, monitor='val_loss', restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(MODEL_SAVE_PATH, 'EfficientNetB1_best_model.keras'),
                                       monitor='val_accuracy',
                                       save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_lr=fine_tune_learning_rate * 0.01)
]

total_epochs = initial_epochs + EPOCHS_FINE_TUNE
history_fine_tune = model.fit(ds_train,
                                epochs=total_epochs,
                                initial_epoch=initial_epochs,
                                validation_data=ds_test,
                                callbacks=fine_tune_callbacks)

print("Fine-tuning complete.")

print(f"Saving the final trained model state to {os.path.join(MODEL_SAVE_PATH, 'EfficientNetB1_final_model.keras')}")
model.save(os.path.join(MODEL_SAVE_PATH, 'EfficientNetB1_final_model.keras'))
print("Final model state saved.")
print(f"Best model saved during training can be found at {os.path.join(MODEL_SAVE_PATH, 'EfficientNetB1_best_model.keras')}")

print(f"Generating training plots and saving to {PLOTS_SAVE_DIR}...")

acc = history.history['accuracy'] + history_fine_tune.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine_tune.history['val_accuracy']
loss = history.history['loss'] + history_fine_tune.history['loss']
val_loss = history.history['val_loss'] + history_fine_tune.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning', linestyle='--')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning', linestyle='--')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.savefig(os.path.join(PLOTS_SAVE_DIR, 'training_validation_curves.png'))
plt.show()

print("Training plots saved.")
# Out:
# 2025-05-06 18:35:47.990668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746536748.008381   45429 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746536748.013572   45429 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746536748.026928   45429 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746536748.026946   45429 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746536748.026948   45429 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746536748.026950   45429 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-06 18:35:48.030899: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading Stanford Dogs dataset...
# I0000 00:00:1746536751.013124   45429 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3029 MB memory:  -> device: 0, name: Quadro P1000, pci bus id: 0000:01:00.0, compute capability: 6.1
# Number of classes: 120
# Dataset preprocessing complete with fixed TF-native augmentation.
# Building the model using EfficientNetB1 with Dropout...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# Compiling the model for initial training...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb1 (Functional)     │ (None, 5, 5, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │       153,720 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,728,959 (25.67 MB)
#  Trainable params: 153,720 (600.47 KB)
#  Non-trainable params: 6,575,239 (25.08 MB)
# Starting initial training (training only the top layers)...
# Epoch 1/10
# 2025-05-06 18:36:14.146612: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746536774.440239   45506 service.cc:152] XLA service 0x781e1c004590 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746536774.440274   45506 service.cc:160]   StreamExecutor device (0): Quadro P1000, Compute Capability 6.1
# 2025-05-06 18:36:14.811950: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746536776.662528   45506 cuda_dnn.cc:529] Loaded cuDNN version 90501
#   1/375 ━━━━━━━━━━━━━━━━━━━━ 3:31:44 34s/step - accuracy: 0.0000e+00 - loss: 4.9427
# I0000 00:00:1746536798.267345   45506 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 117s 223ms/step - accuracy: 0.0589 - loss: 4.5820 - val_accuracy: 0.4298 - val_loss: 3.5683
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 183ms/step - accuracy: 0.4203 - loss: 3.3360 - val_accuracy: 0.6280 - val_loss: 2.6409
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 182ms/step - accuracy: 0.5969 - loss: 2.4675 - val_accuracy: 0.6977 - val_loss: 2.0183
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 181ms/step - accuracy: 0.6777 - loss: 1.9014 - val_accuracy: 0.7290 - val_loss: 1.6199
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 182ms/step - accuracy: 0.7194 - loss: 1.5306 - val_accuracy: 0.7470 - val_loss: 1.3657
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 181ms/step - accuracy: 0.7408 - loss: 1.3025 - val_accuracy: 0.7547 - val_loss: 1.1978
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 181ms/step - accuracy: 0.7607 - loss: 1.1379 - val_accuracy: 0.7624 - val_loss: 1.0845
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 181ms/step - accuracy: 0.7764 - loss: 1.0233 - val_accuracy: 0.7692 - val_loss: 1.0026
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 182ms/step - accuracy: 0.7828 - loss: 0.9349 - val_accuracy: 0.7723 - val_loss: 0.9440
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 69s 182ms/step - accuracy: 0.7916 - loss: 0.8637 - val_accuracy: 0.7760 - val_loss: 0.8989
# Initial training complete.
# Starting fine-tuning (unfreezing and training some base model layers)...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb1 (Functional)     │ (None, 5, 5, 1280)     │     6,575,239 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │       153,720 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,728,959 (25.67 MB)
#  Trainable params: 4,355,976 (16.62 MB)
#  Non-trainable params: 2,372,983 (9.05 MB)
# Epoch 11/50
# 2025-05-06 18:48:44.336175: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:44.504459: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:44.794819: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:45.005756: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:45.273040: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:45.454636: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:46.586044: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:48:46.805319: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-05-06 18:49:05.526293: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 8 bytes spill stores, 8 bytes spill loads
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 140s 257ms/step - accuracy: 0.5822 - loss: 1.8010 - val_accuracy: 0.6930 - val_loss: 1.3063 - learning_rate: 1.0000e-05
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.6695 - loss: 1.3543 - val_accuracy: 0.7161 - val_loss: 1.1478 - learning_rate: 1.0000e-05
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7013 - loss: 1.1624 - val_accuracy: 0.7304 - val_loss: 1.0388 - learning_rate: 1.0000e-05
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7190 - loss: 1.0379 - val_accuracy: 0.7402 - val_loss: 0.9652 - learning_rate: 1.0000e-05
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.7500 - loss: 0.9431 - val_accuracy: 0.7466 - val_loss: 0.9145 - learning_rate: 1.0000e-05
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7485 - loss: 0.9038 - val_accuracy: 0.7523 - val_loss: 0.8811 - learning_rate: 1.0000e-05
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 231ms/step - accuracy: 0.7632 - loss: 0.8576 - val_accuracy: 0.7544 - val_loss: 0.8572 - learning_rate: 1.0000e-05
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7733 - loss: 0.8182 - val_accuracy: 0.7589 - val_loss: 0.8368 - learning_rate: 1.0000e-05
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7833 - loss: 0.7836 - val_accuracy: 0.7607 - val_loss: 0.8205 - learning_rate: 1.0000e-05
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.7877 - loss: 0.7499 - val_accuracy: 0.7638 - val_loss: 0.8063 - learning_rate: 1.0000e-05
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 229ms/step - accuracy: 0.7939 - loss: 0.7358 - val_accuracy: 0.7655 - val_loss: 0.7964 - learning_rate: 1.0000e-05
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.8013 - loss: 0.7007 - val_accuracy: 0.7670 - val_loss: 0.7873 - learning_rate: 1.0000e-05
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.8042 - loss: 0.6922 - val_accuracy: 0.7702 - val_loss: 0.7786 - learning_rate: 1.0000e-05
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.8146 - loss: 0.6726 - val_accuracy: 0.7723 - val_loss: 0.7744 - learning_rate: 1.0000e-05
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 226ms/step - accuracy: 0.8156 - loss: 0.6497 - val_accuracy: 0.7718 - val_loss: 0.7689 - learning_rate: 1.0000e-05
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.8281 - loss: 0.6151 - val_accuracy: 0.7741 - val_loss: 0.7642 - learning_rate: 1.0000e-05
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 226ms/step - accuracy: 0.8315 - loss: 0.5982 - val_accuracy: 0.7737 - val_loss: 0.7602 - learning_rate: 1.0000e-05
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 229ms/step - accuracy: 0.8348 - loss: 0.5835 - val_accuracy: 0.7746 - val_loss: 0.7563 - learning_rate: 1.0000e-05
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 88s 233ms/step - accuracy: 0.8421 - loss: 0.5711 - val_accuracy: 0.7749 - val_loss: 0.7537 - learning_rate: 1.0000e-05
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 89s 236ms/step - accuracy: 0.8446 - loss: 0.5580 - val_accuracy: 0.7753 - val_loss: 0.7523 - learning_rate: 1.0000e-05
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 88s 233ms/step - accuracy: 0.8528 - loss: 0.5302 - val_accuracy: 0.7767 - val_loss: 0.7500 - learning_rate: 1.0000e-05
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 89s 234ms/step - accuracy: 0.8542 - loss: 0.5192 - val_accuracy: 0.7774 - val_loss: 0.7481 - learning_rate: 1.0000e-05
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.8641 - loss: 0.5033 - val_accuracy: 0.7773 - val_loss: 0.7465 - learning_rate: 1.0000e-05
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 88s 232ms/step - accuracy: 0.8719 - loss: 0.4758 - val_accuracy: 0.7790 - val_loss: 0.7448 - learning_rate: 1.0000e-05
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 88s 231ms/step - accuracy: 0.8710 - loss: 0.4767 - val_accuracy: 0.7782 - val_loss: 0.7440 - learning_rate: 1.0000e-05
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 226ms/step - accuracy: 0.8789 - loss: 0.4580 - val_accuracy: 0.7783 - val_loss: 0.7422 - learning_rate: 1.0000e-05
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.8828 - loss: 0.4387 - val_accuracy: 0.7797 - val_loss: 0.7403 - learning_rate: 1.0000e-05
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.8839 - loss: 0.4323 - val_accuracy: 0.7798 - val_loss: 0.7406 - learning_rate: 1.0000e-05
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.8850 - loss: 0.4170 - val_accuracy: 0.7793 - val_loss: 0.7405 - learning_rate: 1.0000e-05
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.8861 - loss: 0.4140 - val_accuracy: 0.7801 - val_loss: 0.7411 - learning_rate: 1.0000e-05
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.8968 - loss: 0.3942 - val_accuracy: 0.7808 - val_loss: 0.7405 - learning_rate: 1.0000e-05
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 226ms/step - accuracy: 0.8942 - loss: 0.3941 - val_accuracy: 0.7789 - val_loss: 0.7403 - learning_rate: 1.0000e-05
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 86s 228ms/step - accuracy: 0.9068 - loss: 0.3689 - val_accuracy: 0.7812 - val_loss: 0.7415 - learning_rate: 1.0000e-05
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9027 - loss: 0.3703
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 87s 230ms/step - accuracy: 0.9027 - loss: 0.3703 - val_accuracy: 0.7828 - val_loss: 0.7425 - learning_rate: 1.0000e-05
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.9169 - loss: 0.3473 - val_accuracy: 0.7826 - val_loss: 0.7417 - learning_rate: 1.0000e-06
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 226ms/step - accuracy: 0.9130 - loss: 0.3494 - val_accuracy: 0.7817 - val_loss: 0.7420 - learning_rate: 1.0000e-06
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.9133 - loss: 0.3468 - val_accuracy: 0.7822 - val_loss: 0.7414 - learning_rate: 1.0000e-06
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.9154 - loss: 0.3448 - val_accuracy: 0.7822 - val_loss: 0.7413 - learning_rate: 1.0000e-06
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.9185 - loss: 0.3387 - val_accuracy: 0.7817 - val_loss: 0.7415 - learning_rate: 1.0000e-06
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 85s 226ms/step - accuracy: 0.9111 - loss: 0.3536 - val_accuracy: 0.7823 - val_loss: 0.7410 - learning_rate: 1.0000e-06
# Fine-tuning complete.
# Saving the final trained model state to ./stanford_dogs_model/EfficientNetB1_final_model.keras
# Final model state saved.
# Best model saved during training can be found at ./stanford_dogs_model/EfficientNetB1_best_model.keras
# Generating training plots and saving to ./training_plots_EfficientNetB1...
# Training plots saved.

# %%
import gc
del model
gc.collect()
tf.keras.backend.clear_session()

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

model = tf.keras.models.load_model('./stanford_dogs_model/EfficientNetB1_final_model.keras')

(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs', 
    split=['train', 'test'],
    with_info=True,
    as_supervised=True
)

ds_all = ds_train.concatenate(ds_test)

IMG_SIZE = model.input_shape[1:3]

def preprocess(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.keras.applications.efficientnet.preprocess_input(image)
    return image, label

autotune = tf.data.AUTOTUNE
batch_size = 32

ds_all = ds_all.map(preprocess, num_parallel_calls=autotune)
ds_all = ds_all.batch(batch_size).prefetch(autotune)

pred_probs = model.predict(ds_all, verbose=1)
pred_labels = np.argmax(pred_probs, axis=1)

true_labels = np.concatenate([y.numpy() for _, y in ds_all], axis=0)

class_names = ds_info.features['label'].names

print(classification_report(true_labels, pred_labels, target_names=class_names))

cm = confusion_matrix(true_labels, pred_labels)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Out:
# 644/644 ━━━━━━━━━━━━━━━━━━━━ 77s 110ms/step
#                                           precision    recall  f1-score   support
#
#                      n02085620-chihuahua       0.85      0.87      0.86       152
#               n02085782-japanese_spaniel       0.90      0.92      0.91       185
#                    n02085936-maltese_dog       0.90      0.93      0.91       252
#                       n02086079-pekinese       0.90      0.91      0.91       149
#                       n02086240-shih-tzu       0.81      0.75      0.78       214
#               n02086646-blenheim_spaniel       0.93      0.93      0.93       188
#                       n02086910-papillon       0.94      0.91      0.93       196
#                    n02087046-toy_terrier       0.88      0.86      0.87       172
#            n02087394-rhodesian_ridgeback       0.87      0.78      0.82       172
#                   n02088094-afghan_hound       0.98      0.94      0.96       239
#                         n02088238-basset       0.88      0.92      0.90       175
#                         n02088364-beagle       0.86      0.81      0.84       195
#                     n02088466-bloodhound       0.94      0.90      0.92       187
#                       n02088632-bluetick       0.94      0.91      0.93       171
#        n02089078-black-and-tan_coonhound       0.92      0.94      0.93       159
#                   n02089867-walker_hound       0.78      0.81      0.80       153
#               n02089973-english_foxhound       0.89      0.87      0.88       157
#                        n02090379-redbone       0.85      0.89      0.87       148
#                         n02090622-borzoi       0.94      0.95      0.94       151
#                n02090721-irish_wolfhound       0.88      0.79      0.83       218
#              n02091032-italian_greyhound       0.89      0.87      0.88       182
#                        n02091134-whippet       0.82      0.87      0.85       187
#                   n02091244-ibizan_hound       0.91      0.93      0.92       188
#             n02091467-norwegian_elkhound       0.94      0.95      0.94       196
#                     n02091635-otterhound       0.89      0.93      0.91       151
#                         n02091831-saluki       0.94      0.89      0.91       200
#             n02092002-scottish_deerhound       0.88      0.90      0.89       232
#                     n02092339-weimaraner       0.95      0.96      0.95       160
#      n02093256-staffordshire_bullterrier       0.82      0.79      0.80       155
# n02093428-american_staffordshire_terrier       0.76      0.77      0.76       164
#             n02093647-bedlington_terrier       0.94      0.97      0.95       182
#                 n02093754-border_terrier       0.94      0.94      0.94       172
#             n02093859-kerry_blue_terrier       0.95      0.93      0.94       179
#                  n02093991-irish_terrier       0.89      0.90      0.89       169
#                n02094114-norfolk_terrier       0.85      0.85      0.85       172
#                n02094258-norwich_terrier       0.86      0.83      0.85       185
#              n02094433-yorkshire_terrier       0.79      0.82      0.81       164
#        n02095314-wire-haired_fox_terrier       0.88      0.90      0.89       157
#               n02095570-lakeland_terrier       0.85      0.83      0.84       197
#               n02095889-sealyham_terrier       0.93      0.94      0.94       202
#                       n02096051-airedale       0.90      0.90      0.90       202
#                          n02096177-cairn       0.87      0.90      0.89       197
#             n02096294-australian_terrier       0.86      0.84      0.85       196
#                 n02096437-dandie_dinmont       0.94      0.92      0.93       180
#                    n02096585-boston_bull       0.91      0.89      0.90       182
#            n02097047-miniature_schnauzer       0.88      0.88      0.88       154
#                n02097130-giant_schnauzer       0.88      0.89      0.89       157
#             n02097209-standard_schnauzer       0.89      0.83      0.86       155
#                 n02097298-scotch_terrier       0.92      0.91      0.92       158
#                n02097474-tibetan_terrier       0.87      0.83      0.85       206
#                  n02097658-silky_terrier       0.86      0.83      0.84       183
#    n02098105-soft-coated_wheaten_terrier       0.88      0.90      0.89       156
#    n02098286-west_highland_white_terrier       0.89      0.93      0.91       169
#                          n02098413-lhasa       0.83      0.79      0.81       186
#          n02099267-flat-coated_retriever       0.91      0.93      0.92       152
#         n02099429-curly-coated_retriever       0.89      0.94      0.92       151
#               n02099601-golden_retriever       0.91      0.92      0.92       150
#             n02099712-labrador_retriever       0.89      0.88      0.89       171
#       n02099849-chesapeake_bay_retriever       0.85      0.95      0.90       167
#    n02100236-german_short-haired_pointer       0.94      0.92      0.93       152
#                         n02100583-vizsla       0.90      0.91      0.91       154
#                 n02100735-english_setter       0.95      0.88      0.91       161
#                   n02100877-irish_setter       0.95      0.95      0.95       155
#                  n02101006-gordon_setter       0.94      0.97      0.95       153
#               n02101388-brittany_spaniel       0.91      0.90      0.90       152
#                        n02101556-clumber       0.94      0.95      0.94       150
#               n02102040-english_springer       0.90      0.93      0.92       159
#         n02102177-welsh_springer_spaniel       0.87      0.92      0.89       150
#                 n02102318-cocker_spaniel       0.93      0.90      0.91       159
#                 n02102480-sussex_spaniel       0.95      0.93      0.94       151
#            n02102973-irish_water_spaniel       0.91      0.98      0.95       150
#                         n02104029-kuvasz       0.89      0.87      0.88       150
#                     n02104365-schipperke       0.95      0.94      0.94       154
#                    n02105056-groenendael       0.92      0.94      0.93       150
#                       n02105162-malinois       0.91      0.95      0.93       150
#                         n02105251-briard       0.88      0.89      0.89       152
#                         n02105412-kelpie       0.86      0.86      0.86       153
#                       n02105505-komondor       0.95      0.96      0.96       154
#           n02105641-old_english_sheepdog       0.94      0.95      0.95       169
#              n02105855-shetland_sheepdog       0.85      0.92      0.88       157
#                         n02106030-collie       0.85      0.67      0.75       153
#                  n02106166-border_collie       0.80      0.89      0.84       150
#           n02106382-bouvier_des_flandres       0.86      0.92      0.89       150
#                     n02106550-rottweiler       0.94      0.95      0.94       152
#                n02106662-german_shepherd       0.89      0.89      0.89       152
#                       n02107142-doberman       0.88      0.91      0.89       150
#             n02107312-miniature_pinscher       0.86      0.88      0.87       184
#     n02107574-greater_swiss_mountain_dog       0.85      0.84      0.85       168
#           n02107683-bernese_mountain_dog       0.91      0.93      0.92       218
#                    n02107908-appenzeller       0.78      0.77      0.78       151
#                    n02108000-entlebucher       0.86      0.85      0.85       202
#                          n02108089-boxer       0.91      0.89      0.90       151
#                   n02108422-bull_mastiff       0.91      0.92      0.92       156
#                n02108551-tibetan_mastiff       0.94      0.89      0.92       152
#                 n02108915-french_bulldog       0.94      0.94      0.94       159
#                     n02109047-great_dane       0.87      0.90      0.88       156
#                  n02109525-saint_bernard       0.97      0.99      0.98       170
#                     n02109961-eskimo_dog       0.67      0.75      0.71       150
#                       n02110063-malamute       0.79      0.84      0.82       178
#                 n02110185-siberian_husky       0.78      0.65      0.71       192
#                  n02110627-affenpinscher       0.92      0.95      0.93       150
#                        n02110806-basenji       0.90      0.86      0.88       209
#                            n02110958-pug       0.93      0.94      0.93       200
#                       n02111129-leonberg       0.95      0.94      0.94       210
#                   n02111277-newfoundland       0.88      0.89      0.88       195
#                 n02111500-great_pyrenees       0.88      0.86      0.87       213
#                        n02111889-samoyed       0.88      0.96      0.92       218
#                     n02112018-pomeranian       0.95      0.91      0.93       219
#                           n02112137-chow       0.95      0.97      0.96       196
#                       n02112350-keeshond       0.97      0.99      0.98       158
#              n02112706-brabancon_griffon       0.94      0.93      0.93       153
#                       n02113023-pembroke       0.88      0.92      0.90       181
#                       n02113186-cardigan       0.82      0.82      0.82       155
#                     n02113624-toy_poodle       0.81      0.81      0.81       151
#               n02113712-miniature_poodle       0.80      0.75      0.78       155
#                n02113799-standard_poodle       0.89      0.88      0.89       159
#               n02113978-mexican_hairless       0.97      0.95      0.96       155
#                          n02115641-dingo       0.89      0.92      0.90       156
#                          n02115913-dhole       0.95      0.97      0.96       150
#            n02116738-african_hunting_dog       0.97      0.99      0.98       169
#
#                                 accuracy                           0.89     20580
#                                macro avg       0.89      0.89      0.89     20580
#                             weighted avg       0.89      0.89      0.89     20580
# 2025-05-06 19:48:23.906891: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import gc
del model
gc.collect()
tf.keras.backend.clear_session()

# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

model = tf.keras.models.load_model('./stanford_dogs_model/EfficientNetB1_best_model.keras')

(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs', 
    split=['train', 'test'],
    with_info=True,
    as_supervised=True
)

ds_all = ds_train.concatenate(ds_test)

IMG_SIZE = model.input_shape[1:3]

def preprocess(image, label):
    image = tf.image.resize(image, IMG_SIZE)
    image = tf.keras.applications.efficientnet.preprocess_input(image)
    return image, label

autotune = tf.data.AUTOTUNE
batch_size = 32

ds_all = ds_all.map(preprocess, num_parallel_calls=autotune)
ds_all = ds_all.batch(batch_size).prefetch(autotune)

pred_probs = model.predict(ds_all, verbose=1)
pred_labels = np.argmax(pred_probs, axis=1)

true_labels = np.concatenate([y.numpy() for _, y in ds_all], axis=0)

class_names = ds_info.features['label'].names

print(classification_report(true_labels, pred_labels, target_names=class_names))

cm = confusion_matrix(true_labels, pred_labels)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Out:
# 644/644 ━━━━━━━━━━━━━━━━━━━━ 77s 110ms/step
#                                           precision    recall  f1-score   support
#
#                      n02085620-chihuahua       0.83      0.86      0.85       152
#               n02085782-japanese_spaniel       0.89      0.93      0.91       185
#                    n02085936-maltese_dog       0.90      0.92      0.91       252
#                       n02086079-pekinese       0.90      0.91      0.91       149
#                       n02086240-shih-tzu       0.82      0.75      0.78       214
#               n02086646-blenheim_spaniel       0.93      0.93      0.93       188
#                       n02086910-papillon       0.94      0.91      0.92       196
#                    n02087046-toy_terrier       0.89      0.87      0.88       172
#            n02087394-rhodesian_ridgeback       0.88      0.79      0.83       172
#                   n02088094-afghan_hound       0.98      0.94      0.96       239
#                         n02088238-basset       0.88      0.93      0.90       175
#                         n02088364-beagle       0.87      0.82      0.84       195
#                     n02088466-bloodhound       0.94      0.90      0.92       187
#                       n02088632-bluetick       0.95      0.91      0.93       171
#        n02089078-black-and-tan_coonhound       0.92      0.95      0.93       159
#                   n02089867-walker_hound       0.81      0.82      0.81       153
#               n02089973-english_foxhound       0.89      0.89      0.89       157
#                        n02090379-redbone       0.87      0.91      0.89       148
#                         n02090622-borzoi       0.95      0.95      0.95       151
#                n02090721-irish_wolfhound       0.90      0.81      0.85       218
#              n02091032-italian_greyhound       0.89      0.87      0.88       182
#                        n02091134-whippet       0.83      0.87      0.85       187
#                   n02091244-ibizan_hound       0.91      0.93      0.92       188
#             n02091467-norwegian_elkhound       0.94      0.95      0.94       196
#                     n02091635-otterhound       0.89      0.93      0.91       151
#                         n02091831-saluki       0.95      0.90      0.92       200
#             n02092002-scottish_deerhound       0.89      0.91      0.90       232
#                     n02092339-weimaraner       0.95      0.96      0.95       160
#      n02093256-staffordshire_bullterrier       0.83      0.79      0.81       155
# n02093428-american_staffordshire_terrier       0.77      0.79      0.78       164
#             n02093647-bedlington_terrier       0.94      0.97      0.96       182
#                 n02093754-border_terrier       0.93      0.95      0.94       172
#             n02093859-kerry_blue_terrier       0.96      0.93      0.94       179
#                  n02093991-irish_terrier       0.89      0.90      0.89       169
#                n02094114-norfolk_terrier       0.84      0.85      0.85       172
#                n02094258-norwich_terrier       0.86      0.85      0.85       185
#              n02094433-yorkshire_terrier       0.80      0.82      0.81       164
#        n02095314-wire-haired_fox_terrier       0.89      0.90      0.89       157
#               n02095570-lakeland_terrier       0.85      0.84      0.84       197
#               n02095889-sealyham_terrier       0.92      0.94      0.93       202
#                       n02096051-airedale       0.90      0.91      0.90       202
#                          n02096177-cairn       0.91      0.90      0.91       197
#             n02096294-australian_terrier       0.87      0.84      0.85       196
#                 n02096437-dandie_dinmont       0.93      0.92      0.93       180
#                    n02096585-boston_bull       0.91      0.89      0.90       182
#            n02097047-miniature_schnauzer       0.88      0.88      0.88       154
#                n02097130-giant_schnauzer       0.87      0.90      0.88       157
#             n02097209-standard_schnauzer       0.88      0.83      0.85       155
#                 n02097298-scotch_terrier       0.92      0.92      0.92       158
#                n02097474-tibetan_terrier       0.88      0.83      0.85       206
#                  n02097658-silky_terrier       0.86      0.84      0.85       183
#    n02098105-soft-coated_wheaten_terrier       0.89      0.90      0.89       156
#    n02098286-west_highland_white_terrier       0.89      0.93      0.91       169
#                          n02098413-lhasa       0.83      0.79      0.81       186
#          n02099267-flat-coated_retriever       0.90      0.93      0.92       152
#         n02099429-curly-coated_retriever       0.90      0.95      0.92       151
#               n02099601-golden_retriever       0.93      0.92      0.93       150
#             n02099712-labrador_retriever       0.91      0.88      0.90       171
#       n02099849-chesapeake_bay_retriever       0.83      0.95      0.89       167
#    n02100236-german_short-haired_pointer       0.95      0.93      0.94       152
#                         n02100583-vizsla       0.89      0.92      0.91       154
#                 n02100735-english_setter       0.95      0.88      0.91       161
#                   n02100877-irish_setter       0.96      0.97      0.96       155
#                  n02101006-gordon_setter       0.95      0.96      0.95       153
#               n02101388-brittany_spaniel       0.91      0.91      0.91       152
#                        n02101556-clumber       0.94      0.95      0.94       150
#               n02102040-english_springer       0.90      0.94      0.92       159
#         n02102177-welsh_springer_spaniel       0.87      0.92      0.90       150
#                 n02102318-cocker_spaniel       0.93      0.90      0.91       159
#                 n02102480-sussex_spaniel       0.95      0.93      0.94       151
#            n02102973-irish_water_spaniel       0.91      0.99      0.95       150
#                         n02104029-kuvasz       0.88      0.88      0.88       150
#                     n02104365-schipperke       0.95      0.94      0.94       154
#                    n02105056-groenendael       0.90      0.95      0.93       150
#                       n02105162-malinois       0.91      0.96      0.93       150
#                         n02105251-briard       0.89      0.91      0.90       152
#                         n02105412-kelpie       0.85      0.86      0.86       153
#                       n02105505-komondor       0.95      0.96      0.96       154
#           n02105641-old_english_sheepdog       0.97      0.95      0.96       169
#              n02105855-shetland_sheepdog       0.88      0.92      0.90       157
#                         n02106030-collie       0.88      0.69      0.77       153
#                  n02106166-border_collie       0.80      0.90      0.85       150
#           n02106382-bouvier_des_flandres       0.88      0.91      0.90       150
#                     n02106550-rottweiler       0.94      0.95      0.94       152
#                n02106662-german_shepherd       0.91      0.89      0.90       152
#                       n02107142-doberman       0.87      0.91      0.89       150
#             n02107312-miniature_pinscher       0.86      0.87      0.87       184
#     n02107574-greater_swiss_mountain_dog       0.87      0.86      0.86       168
#           n02107683-bernese_mountain_dog       0.91      0.93      0.92       218
#                    n02107908-appenzeller       0.79      0.76      0.77       151
#                    n02108000-entlebucher       0.87      0.85      0.86       202
#                          n02108089-boxer       0.91      0.89      0.90       151
#                   n02108422-bull_mastiff       0.91      0.93      0.92       156
#                n02108551-tibetan_mastiff       0.94      0.90      0.92       152
#                 n02108915-french_bulldog       0.93      0.94      0.94       159
#                     n02109047-great_dane       0.88      0.91      0.90       156
#                  n02109525-saint_bernard       0.97      0.99      0.98       170
#                     n02109961-eskimo_dog       0.67      0.77      0.71       150
#                       n02110063-malamute       0.80      0.83      0.82       178
#                 n02110185-siberian_husky       0.78      0.65      0.71       192
#                  n02110627-affenpinscher       0.93      0.95      0.94       150
#                        n02110806-basenji       0.91      0.86      0.88       209
#                            n02110958-pug       0.94      0.94      0.94       200
#                       n02111129-leonberg       0.95      0.94      0.94       210
#                   n02111277-newfoundland       0.87      0.90      0.88       195
#                 n02111500-great_pyrenees       0.90      0.84      0.87       213
#                        n02111889-samoyed       0.86      0.98      0.91       218
#                     n02112018-pomeranian       0.95      0.91      0.93       219
#                           n02112137-chow       0.96      0.97      0.96       196
#                       n02112350-keeshond       0.98      0.99      0.98       158
#              n02112706-brabancon_griffon       0.95      0.93      0.94       153
#                       n02113023-pembroke       0.88      0.93      0.91       181
#                       n02113186-cardigan       0.83      0.83      0.83       155
#                     n02113624-toy_poodle       0.80      0.81      0.81       151
#               n02113712-miniature_poodle       0.81      0.76      0.78       155
#                n02113799-standard_poodle       0.88      0.89      0.88       159
#               n02113978-mexican_hairless       0.97      0.95      0.96       155
#                          n02115641-dingo       0.89      0.92      0.90       156
#                          n02115913-dhole       0.95      0.97      0.96       150
#            n02116738-african_hunting_dog       0.97      0.99      0.98       169
#
#                                 accuracy                           0.90     20580
#                                macro avg       0.90      0.90      0.89     20580
#                             weighted avg       0.90      0.90      0.89     20580
# 2025-05-06 19:49:53.851172: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
